# %%
from os import listdir
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from PIL import Image
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import random

# %%
def load_photos(directory):
    images = []
    labels_speed = []
    labels_dir = []
    dir_list = listdir(directory)
    #random.shuffle(dir_list)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename, target_size=(96, 160))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # get image id + labels
        value_dir = float(name.split('_')[1])
        value_speed = float(name.split('_')[0])
        labels_dir.append(value_dir)
        labels_speed.append(value_speed)
        images.append(image)
    return images, labels_speed, labels_dir

# %%
#dataset = "../../Pics/TestTrack/cleaned1"
#dataset = "../../Pics/TestTrack/mirrored1"
#dataset = "../../Pics/TestTrack/tagged2"
#dataset = "../../Pics/TestTrack/mirrored2"
#dataset = "../../Pics/TestTrack/test_noFE_mirrored"

#dataset = "../../Pics/RaceTrack/OldDataset_balanced"
#dataset = "../../Pics/RaceTrack/Datasets_Axionable/ironcar_pics"
#dataset = "../../Pics/RaceTrack/Mixed"
dataset = "../../Pics/RaceTrack/OldDataset_3"

# %%
# load images from both train and test groups
directory = '../../'+dataset+'/Train'
images, labels_speed, labels_dir = load_photos(directory)
nb_images = len(images)
print('Loaded Images and labels for training: %d' % nb_images)
directory = '../../'+dataset+'/Val'
images_val, labels_speed_val, labels_dir_val = load_photos(directory)
nb_images_val = len(images_val)
print('Loaded Images and labels for validation: %d' % nb_images_val)
# Out:
# Loaded Images and labels for training: 1210
# Loaded Images and labels for validation: 250

# %%
#Normalise images
images = np.array(images)
images /= 255

# %%
#convert datas to dummyvalues
labels_speed = np.array(pd.get_dummies(labels_speed))
labels_dir = np.array(pd.get_dummies(labels_dir))

# %%
labels_speed[42], labels_dir[42], plt.imshow(images[42])
# Out:
# (array([1, 0], dtype=uint8),
#  array([1, 0, 0], dtype=uint8),
#  <matplotlib.image.AxesImage at 0x24a5778bac8>)

# %%
from keras.models import Model, Sequential
from keras.layers import *
import keras.backend as K
import keras.optimizers as Optimizers

# %%
K.clear_session()
############################################################# Multitask Model 2

img_in = Input(shape=(96, 160, 3), name='img_in')
x = img_in

x = Convolution2D(8, (8,4), strides=(4,4), activation='relu')(x)
x = Convolution2D(8, (2,1), strides=(2,2), activation='relu')(x)
x = Convolution2D(8, (1,1), strides=(1,1), activation='relu')(x)

x = BatchNormalization()(x)

x = Flatten()(x)

x = Dense(8, activation='relu')(x)
x = Dropout(0.4)(x)

out_speed = Dense(2, activation='softmax')(x)
out_dir = Dense(3, activation='softmax')(x)

model = Model(inputs=[img_in], outputs=[out_speed, out_dir])
model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_in (InputLayer)             (None, 96, 160, 3)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 23, 40, 8)    776         img_in[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 11, 20, 8)    136         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 11, 20, 8)    72          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 11, 20, 8)    32          conv2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1760)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            14088       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            18          dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            27          dropout_1[0][0]
# ==================================================================================================
# Total params: 15,149
# Trainable params: 15,133
# Non-trainable params: 16
# __________________________________________________________________________________________________

# %%
h = model.fit(images, [labels_speed, labels_dir], batch_size=128, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 1.6892 - dense_2_loss: 0.6602 - dense_3_loss: 1.0290 - dense_2_acc: 0.6008 - dense_3_acc: 0.5008
# Epoch 2/100
# 1210/1210 [==============================] - 1s 959us/step - loss: 1.5177 - dense_2_loss: 0.5748 - dense_3_loss: 0.9429 - dense_2_acc: 0.7083 - dense_3_acc: 0.5702
# Epoch 3/100
# 1210/1210 [==============================] - 1s 912us/step - loss: 1.4440 - dense_2_loss: 0.5456 - dense_3_loss: 0.8984 - dense_2_acc: 0.7157 - dense_3_acc: 0.5926
# Epoch 4/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 1.3895 - dense_2_loss: 0.5316 - dense_3_loss: 0.8579 - dense_2_acc: 0.7488 - dense_3_acc: 0.6174
# Epoch 5/100
# 1210/1210 [==============================] - 1s 978us/step - loss: 1.3403 - dense_2_loss: 0.5037 - dense_3_loss: 0.8366 - dense_2_acc: 0.7579 - dense_3_acc: 0.6165
# Epoch 6/100
# 1210/1210 [==============================] - 1s 950us/step - loss: 1.3045 - dense_2_loss: 0.4897 - dense_3_loss: 0.8148 - dense_2_acc: 0.7612 - dense_3_acc: 0.6339
# Epoch 7/100
# 1210/1210 [==============================] - 1s 995us/step - loss: 1.2616 - dense_2_loss: 0.4573 - dense_3_loss: 0.8043 - dense_2_acc: 0.7959 - dense_3_acc: 0.6331
# Epoch 8/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 1.2383 - dense_2_loss: 0.4533 - dense_3_loss: 0.7850 - dense_2_acc: 0.7917 - dense_3_acc: 0.6512
# Epoch 9/100
# 1210/1210 [==============================] - 1s 983us/step - loss: 1.2240 - dense_2_loss: 0.4494 - dense_3_loss: 0.7746 - dense_2_acc: 0.8207 - dense_3_acc: 0.6430
# Epoch 10/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 1.1921 - dense_2_loss: 0.4458 - dense_3_loss: 0.7463 - dense_2_acc: 0.8074 - dense_3_acc: 0.6620
# Epoch 11/100
# 1210/1210 [==============================] - 1s 947us/step - loss: 1.2104 - dense_2_loss: 0.4452 - dense_3_loss: 0.7652 - dense_2_acc: 0.8091 - dense_3_acc: 0.6306
# Epoch 12/100
# 1210/1210 [==============================] - 1s 907us/step - loss: 1.1621 - dense_2_loss: 0.4273 - dense_3_loss: 0.7348 - dense_2_acc: 0.8140 - dense_3_acc: 0.6512
# Epoch 13/100
# 1210/1210 [==============================] - 1s 908us/step - loss: 1.1215 - dense_2_loss: 0.3986 - dense_3_loss: 0.7229 - dense_2_acc: 0.8355 - dense_3_acc: 0.6612
# Epoch 14/100
# 1210/1210 [==============================] - 1s 944us/step - loss: 1.1160 - dense_2_loss: 0.3803 - dense_3_loss: 0.7358 - dense_2_acc: 0.8455 - dense_3_acc: 0.6496
# Epoch 15/100
# 1210/1210 [==============================] - 1s 944us/step - loss: 1.1000 - dense_2_loss: 0.4047 - dense_3_loss: 0.6953 - dense_2_acc: 0.8298 - dense_3_acc: 0.6851
# Epoch 16/100
# 1210/1210 [==============================] - 1s 967us/step - loss: 1.1228 - dense_2_loss: 0.3990 - dense_3_loss: 0.7238 - dense_2_acc: 0.8388 - dense_3_acc: 0.6529
# Epoch 17/100
# 1210/1210 [==============================] - 1s 974us/step - loss: 1.0688 - dense_2_loss: 0.3846 - dense_3_loss: 0.6842 - dense_2_acc: 0.8380 - dense_3_acc: 0.6736
# Epoch 18/100
# 1210/1210 [==============================] - 1s 976us/step - loss: 1.0631 - dense_2_loss: 0.3773 - dense_3_loss: 0.6858 - dense_2_acc: 0.8463 - dense_3_acc: 0.6694
# Epoch 19/100
# 1210/1210 [==============================] - 1s 946us/step - loss: 1.0264 - dense_2_loss: 0.3585 - dense_3_loss: 0.6680 - dense_2_acc: 0.8529 - dense_3_acc: 0.6752
# Epoch 20/100
# 1210/1210 [==============================] - 1s 976us/step - loss: 1.0380 - dense_2_loss: 0.3410 - dense_3_loss: 0.6970 - dense_2_acc: 0.8488 - dense_3_acc: 0.6529
# Epoch 21/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 0.9825 - dense_2_loss: 0.3539 - dense_3_loss: 0.6286 - dense_2_acc: 0.8628 - dense_3_acc: 0.6992
# Epoch 22/100
# 1210/1210 [==============================] - 1s 966us/step - loss: 1.0004 - dense_2_loss: 0.3535 - dense_3_loss: 0.6469 - dense_2_acc: 0.8496 - dense_3_acc: 0.6835
# Epoch 23/100
# 1210/1210 [==============================] - 1s 967us/step - loss: 0.9955 - dense_2_loss: 0.3399 - dense_3_loss: 0.6555 - dense_2_acc: 0.8603 - dense_3_acc: 0.6893
# Epoch 24/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 0.9777 - dense_2_loss: 0.3429 - dense_3_loss: 0.6348 - dense_2_acc: 0.8595 - dense_3_acc: 0.6826
# Epoch 25/100
# 1210/1210 [==============================] - 1s 938us/step - loss: 0.9581 - dense_2_loss: 0.3400 - dense_3_loss: 0.6181 - dense_2_acc: 0.8554 - dense_3_acc: 0.6926
# Epoch 26/100
# 1210/1210 [==============================] - 1s 958us/step - loss: 0.9393 - dense_2_loss: 0.3373 - dense_3_loss: 0.6019 - dense_2_acc: 0.8727 - dense_3_acc: 0.6942
# Epoch 27/100
# 1210/1210 [==============================] - 1s 918us/step - loss: 0.9391 - dense_2_loss: 0.3343 - dense_3_loss: 0.6048 - dense_2_acc: 0.8669 - dense_3_acc: 0.6950
# Epoch 28/100
# 1210/1210 [==============================] - 1s 903us/step - loss: 0.9056 - dense_2_loss: 0.2992 - dense_3_loss: 0.6064 - dense_2_acc: 0.8901 - dense_3_acc: 0.7033
# Epoch 29/100
# 1210/1210 [==============================] - 1s 919us/step - loss: 0.8702 - dense_2_loss: 0.3053 - dense_3_loss: 0.5649 - dense_2_acc: 0.8785 - dense_3_acc: 0.7165
# Epoch 30/100
# 1210/1210 [==============================] - 1s 912us/step - loss: 0.8977 - dense_2_loss: 0.3060 - dense_3_loss: 0.5917 - dense_2_acc: 0.8769 - dense_3_acc: 0.6901
# Epoch 31/100
# 1210/1210 [==============================] - 1s 911us/step - loss: 0.8702 - dense_2_loss: 0.3089 - dense_3_loss: 0.5613 - dense_2_acc: 0.8736 - dense_3_acc: 0.7198
# Epoch 32/100
# 1210/1210 [==============================] - 1s 912us/step - loss: 0.8746 - dense_2_loss: 0.3048 - dense_3_loss: 0.5698 - dense_2_acc: 0.8802 - dense_3_acc: 0.7140
# Epoch 33/100
# 1210/1210 [==============================] - 1s 966us/step - loss: 0.8584 - dense_2_loss: 0.2940 - dense_3_loss: 0.5644 - dense_2_acc: 0.8810 - dense_3_acc: 0.7140
# Epoch 34/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 0.8333 - dense_2_loss: 0.2877 - dense_3_loss: 0.5456 - dense_2_acc: 0.8917 - dense_3_acc: 0.7198
# Epoch 35/100
# 1210/1210 [==============================] - 1s 973us/step - loss: 0.8072 - dense_2_loss: 0.2773 - dense_3_loss: 0.5299 - dense_2_acc: 0.8868 - dense_3_acc: 0.7322
# Epoch 36/100
# 1210/1210 [==============================] - 1s 941us/step - loss: 0.7986 - dense_2_loss: 0.2692 - dense_3_loss: 0.5293 - dense_2_acc: 0.8967 - dense_3_acc: 0.7314
# Epoch 37/100
# 1210/1210 [==============================] - 1s 965us/step - loss: 0.7966 - dense_2_loss: 0.2740 - dense_3_loss: 0.5226 - dense_2_acc: 0.8909 - dense_3_acc: 0.7339
# Epoch 38/100
# 1210/1210 [==============================] - 1s 944us/step - loss: 0.8295 - dense_2_loss: 0.2756 - dense_3_loss: 0.5540 - dense_2_acc: 0.8917 - dense_3_acc: 0.7256
# Epoch 39/100
# 1210/1210 [==============================] - 1s 989us/step - loss: 0.8167 - dense_2_loss: 0.2709 - dense_3_loss: 0.5459 - dense_2_acc: 0.8934 - dense_3_acc: 0.7099
# Epoch 40/100
# 1210/1210 [==============================] - 1s 930us/step - loss: 0.7515 - dense_2_loss: 0.2591 - dense_3_loss: 0.4924 - dense_2_acc: 0.8934 - dense_3_acc: 0.7496
# Epoch 41/100
# 1210/1210 [==============================] - 1s 989us/step - loss: 0.7571 - dense_2_loss: 0.2640 - dense_3_loss: 0.4932 - dense_2_acc: 0.8975 - dense_3_acc: 0.7397
# Epoch 42/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 0.7602 - dense_2_loss: 0.2524 - dense_3_loss: 0.5078 - dense_2_acc: 0.9025 - dense_3_acc: 0.7488
# Epoch 43/100
# 1210/1210 [==============================] - 1s 979us/step - loss: 0.7650 - dense_2_loss: 0.2603 - dense_3_loss: 0.5047 - dense_2_acc: 0.8975 - dense_3_acc: 0.7471
# Epoch 44/100
# 1210/1210 [==============================] - 1s 978us/step - loss: 0.7350 - dense_2_loss: 0.2449 - dense_3_loss: 0.4901 - dense_2_acc: 0.9041 - dense_3_acc: 0.7430
# Epoch 45/100
# 1210/1210 [==============================] - 1s 929us/step - loss: 0.7235 - dense_2_loss: 0.2432 - dense_3_loss: 0.4803 - dense_2_acc: 0.9017 - dense_3_acc: 0.7421
# Epoch 46/100
# 1210/1210 [==============================] - 1s 886us/step - loss: 0.7447 - dense_2_loss: 0.2523 - dense_3_loss: 0.4924 - dense_2_acc: 0.8983 - dense_3_acc: 0.7397
# Epoch 47/100
# 1210/1210 [==============================] - 1s 893us/step - loss: 0.6898 - dense_2_loss: 0.2354 - dense_3_loss: 0.4543 - dense_2_acc: 0.9066 - dense_3_acc: 0.7702
# Epoch 48/100
# 1210/1210 [==============================] - 1s 919us/step - loss: 0.6699 - dense_2_loss: 0.2156 - dense_3_loss: 0.4543 - dense_2_acc: 0.9198 - dense_3_acc: 0.7636
# Epoch 49/100
# 1210/1210 [==============================] - 1s 917us/step - loss: 0.7122 - dense_2_loss: 0.2418 - dense_3_loss: 0.4704 - dense_2_acc: 0.9041 - dense_3_acc: 0.7669
# Epoch 50/100
# 1210/1210 [==============================] - 1s 865us/step - loss: 0.7072 - dense_2_loss: 0.2330 - dense_3_loss: 0.4742 - dense_2_acc: 0.9066 - dense_3_acc: 0.7545
# Epoch 51/100
# 1210/1210 [==============================] - 1s 918us/step - loss: 0.6849 - dense_2_loss: 0.2328 - dense_3_loss: 0.4521 - dense_2_acc: 0.9099 - dense_3_acc: 0.7744
# Epoch 52/100
# 1210/1210 [==============================] - 1s 860us/step - loss: 0.6977 - dense_2_loss: 0.2429 - dense_3_loss: 0.4548 - dense_2_acc: 0.9025 - dense_3_acc: 0.7694
# Epoch 53/100
# 1210/1210 [==============================] - 1s 845us/step - loss: 0.6908 - dense_2_loss: 0.2330 - dense_3_loss: 0.4579 - dense_2_acc: 0.9066 - dense_3_acc: 0.7736
# Epoch 54/100
# 1210/1210 [==============================] - 1s 911us/step - loss: 0.6458 - dense_2_loss: 0.2138 - dense_3_loss: 0.4320 - dense_2_acc: 0.9198 - dense_3_acc: 0.7934
# Epoch 55/100
# 1210/1210 [==============================] - 1s 946us/step - loss: 0.6645 - dense_2_loss: 0.2166 - dense_3_loss: 0.4479 - dense_2_acc: 0.9165 - dense_3_acc: 0.7727
# Epoch 56/100
# 1210/1210 [==============================] - 1s 899us/step - loss: 0.6486 - dense_2_loss: 0.2199 - dense_3_loss: 0.4287 - dense_2_acc: 0.9091 - dense_3_acc: 0.7736
# Epoch 57/100
# 1210/1210 [==============================] - 1s 888us/step - loss: 0.6655 - dense_2_loss: 0.2234 - dense_3_loss: 0.4421 - dense_2_acc: 0.9149 - dense_3_acc: 0.7752
# Epoch 58/100
# 1210/1210 [==============================] - 1s 925us/step - loss: 0.6017 - dense_2_loss: 0.1909 - dense_3_loss: 0.4108 - dense_2_acc: 0.9314 - dense_3_acc: 0.8033
# Epoch 59/100
# 1210/1210 [==============================] - 1s 883us/step - loss: 0.6405 - dense_2_loss: 0.2085 - dense_3_loss: 0.4320 - dense_2_acc: 0.9215 - dense_3_acc: 0.7752
# Epoch 60/100
# 1210/1210 [==============================] - 1s 981us/step - loss: 0.6596 - dense_2_loss: 0.2142 - dense_3_loss: 0.4454 - dense_2_acc: 0.9174 - dense_3_acc: 0.7702
# Epoch 61/100
# 1210/1210 [==============================] - 1s 848us/step - loss: 0.6043 - dense_2_loss: 0.1967 - dense_3_loss: 0.4075 - dense_2_acc: 0.9207 - dense_3_acc: 0.7876
# Epoch 62/100
# 1210/1210 [==============================] - 1s 839us/step - loss: 0.5910 - dense_2_loss: 0.2059 - dense_3_loss: 0.3850 - dense_2_acc: 0.9132 - dense_3_acc: 0.8033
# Epoch 63/100
# 1210/1210 [==============================] - 1s 904us/step - loss: 0.5967 - dense_2_loss: 0.1842 - dense_3_loss: 0.4125 - dense_2_acc: 0.9281 - dense_3_acc: 0.7934
# Epoch 64/100
# 1210/1210 [==============================] - 1s 899us/step - loss: 0.6016 - dense_2_loss: 0.2008 - dense_3_loss: 0.4008 - dense_2_acc: 0.9207 - dense_3_acc: 0.7992
# Epoch 65/100
# 1210/1210 [==============================] - 1s 861us/step - loss: 0.5743 - dense_2_loss: 0.1831 - dense_3_loss: 0.3913 - dense_2_acc: 0.9306 - dense_3_acc: 0.7942
# Epoch 66/100
# 1210/1210 [==============================] - 1s 908us/step - loss: 0.5962 - dense_2_loss: 0.2041 - dense_3_loss: 0.3921 - dense_2_acc: 0.9099 - dense_3_acc: 0.8000
# Epoch 67/100
# 1210/1210 [==============================] - 1s 966us/step - loss: 0.5788 - dense_2_loss: 0.1903 - dense_3_loss: 0.3885 - dense_2_acc: 0.9223 - dense_3_acc: 0.7851
# Epoch 68/100
# 1210/1210 [==============================] - 1s 922us/step - loss: 0.5854 - dense_2_loss: 0.1998 - dense_3_loss: 0.3856 - dense_2_acc: 0.9256 - dense_3_acc: 0.8091
# Epoch 69/100
# 1210/1210 [==============================] - 1s 888us/step - loss: 0.5830 - dense_2_loss: 0.1896 - dense_3_loss: 0.3934 - dense_2_acc: 0.9281 - dense_3_acc: 0.7992
# Epoch 70/100
# 1210/1210 [==============================] - 1s 837us/step - loss: 0.5691 - dense_2_loss: 0.1826 - dense_3_loss: 0.3866 - dense_2_acc: 0.9331 - dense_3_acc: 0.8017
# Epoch 71/100
# 1210/1210 [==============================] - 1s 967us/step - loss: 0.5681 - dense_2_loss: 0.1825 - dense_3_loss: 0.3856 - dense_2_acc: 0.9306 - dense_3_acc: 0.8050
# Epoch 72/100
# 1210/1210 [==============================] - 1s 919us/step - loss: 0.5446 - dense_2_loss: 0.1784 - dense_3_loss: 0.3663 - dense_2_acc: 0.9273 - dense_3_acc: 0.8215
# Epoch 73/100
# 1210/1210 [==============================] - 1s 886us/step - loss: 0.5558 - dense_2_loss: 0.1749 - dense_3_loss: 0.3809 - dense_2_acc: 0.9273 - dense_3_acc: 0.8041
# Epoch 74/100
# 1210/1210 [==============================] - 1s 873us/step - loss: 0.5717 - dense_2_loss: 0.1946 - dense_3_loss: 0.3771 - dense_2_acc: 0.9256 - dense_3_acc: 0.8099
# Epoch 75/100
# 1210/1210 [==============================] - 1s 861us/step - loss: 0.5524 - dense_2_loss: 0.1805 - dense_3_loss: 0.3719 - dense_2_acc: 0.9264 - dense_3_acc: 0.8066
# Epoch 76/100
# 1210/1210 [==============================] - 1s 891us/step - loss: 0.5322 - dense_2_loss: 0.1744 - dense_3_loss: 0.3578 - dense_2_acc: 0.9273 - dense_3_acc: 0.8124
# Epoch 77/100
# 1210/1210 [==============================] - 1s 879us/step - loss: 0.5492 - dense_2_loss: 0.1794 - dense_3_loss: 0.3698 - dense_2_acc: 0.9289 - dense_3_acc: 0.8050
# Epoch 78/100
# 1210/1210 [==============================] - 1s 977us/step - loss: 0.5701 - dense_2_loss: 0.1879 - dense_3_loss: 0.3822 - dense_2_acc: 0.9231 - dense_3_acc: 0.7975
# Epoch 79/100
# 1210/1210 [==============================] - 1s 1ms/step - loss: 0.5653 - dense_2_loss: 0.1789 - dense_3_loss: 0.3864 - dense_2_acc: 0.9339 - dense_3_acc: 0.7926
# Epoch 80/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5400 - dense_2_loss: 0.1676 - dense_3_loss: 0.3725 - dense_2_acc: 0.9322 - dense_3_acc: 0.8000
# Epoch 81/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5059 - dense_2_loss: 0.1695 - dense_3_loss: 0.3364 - dense_2_acc: 0.9289 - dense_3_acc: 0.8273
# Epoch 82/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5973 - dense_2_loss: 0.2026 - dense_3_loss: 0.3946 - dense_2_acc: 0.9140 - dense_3_acc: 0.7934
# Epoch 83/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5426 - dense_2_loss: 0.1756 - dense_3_loss: 0.3670 - dense_2_acc: 0.9314 - dense_3_acc: 0.8074
# Epoch 84/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5001 - dense_2_loss: 0.1674 - dense_3_loss: 0.3327 - dense_2_acc: 0.9339 - dense_3_acc: 0.8157
# Epoch 85/100
# 1210/1210 [==============================] - 2s 2ms/step - loss: 0.5098 - dense_2_loss: 0.1664 - dense_3_loss: 0.3433 - dense_2_acc: 0.9306 - dense_3_acc: 0.8140
# Epoch 86/100
# 1210/1210 [==============================] - 2s 2ms/step - loss: 0.4963 - dense_2_loss: 0.1588 - dense_3_loss: 0.3375 - dense_2_acc: 0.9364 - dense_3_acc: 0.8198
# Epoch 87/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5238 - dense_2_loss: 0.1640 - dense_3_loss: 0.3598 - dense_2_acc: 0.9322 - dense_3_acc: 0.8050
# Epoch 88/100
# 1210/1210 [==============================] - 2s 2ms/step - loss: 0.5163 - dense_2_loss: 0.1684 - dense_3_loss: 0.3478 - dense_2_acc: 0.9322 - dense_3_acc: 0.8017
# Epoch 89/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5238 - dense_2_loss: 0.1763 - dense_3_loss: 0.3475 - dense_2_acc: 0.9264 - dense_3_acc: 0.8198
# Epoch 90/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5100 - dense_2_loss: 0.1729 - dense_3_loss: 0.3371 - dense_2_acc: 0.9298 - dense_3_acc: 0.8240
# Epoch 91/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.4909 - dense_2_loss: 0.1493 - dense_3_loss: 0.3416 - dense_2_acc: 0.9322 - dense_3_acc: 0.8132
# Epoch 92/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5287 - dense_2_loss: 0.1736 - dense_3_loss: 0.3551 - dense_2_acc: 0.9306 - dense_3_acc: 0.8215
# Epoch 93/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.4916 - dense_2_loss: 0.1671 - dense_3_loss: 0.3245 - dense_2_acc: 0.9347 - dense_3_acc: 0.8430
# Epoch 94/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5233 - dense_2_loss: 0.1569 - dense_3_loss: 0.3664 - dense_2_acc: 0.9405 - dense_3_acc: 0.8140
# Epoch 95/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.4950 - dense_2_loss: 0.1615 - dense_3_loss: 0.3336 - dense_2_acc: 0.9397 - dense_3_acc: 0.8355
# Epoch 96/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5427 - dense_2_loss: 0.1806 - dense_3_loss: 0.3621 - dense_2_acc: 0.9256 - dense_3_acc: 0.8256
# Epoch 97/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.4897 - dense_2_loss: 0.1567 - dense_3_loss: 0.3329 - dense_2_acc: 0.9331 - dense_3_acc: 0.8421
# Epoch 98/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.4946 - dense_2_loss: 0.1644 - dense_3_loss: 0.3301 - dense_2_acc: 0.9314 - dense_3_acc: 0.8430
# Epoch 99/100
# 1210/1210 [==============================] - 2s 1ms/step - loss: 0.5020 - dense_2_loss: 0.1662 - dense_3_loss: 0.3358 - dense_2_acc: 0.9347 - dense_3_acc: 0.8331
# Epoch 100/100
# 1210/1210 [==============================] - 2s 2ms/step - loss: 0.4786 - dense_2_loss: 0.1605 - dense_3_loss: 0.3182 - dense_2_acc: 0.9322 - dense_3_acc: 0.8529

# %%
#print History graph
historydf = pd.DataFrame(h.history, index=h.epoch)
historydf.plot(ylim=(0,1))

# %%
model.save('model_multi3_lt.h5')

# %%
#######################  VALIDATION

# %%
images_val = np.array(images_val)
images_val /= 255

# %%
# Get predictions
all_preds = model.predict(images_val)

speed_preds = []
for elem in all_preds[0]:
    speed_preds.append(np.argmax(elem))
    
dir_preds = []
for elem in all_preds[1]:
    dir_preds.append(np.argmax(elem))

# %%
res = 0
for i, value in enumerate(speed_preds):
    if value != labels_speed_val[i]:
        res += 1
print("error_rate = " + str(res/i))
# Out:
# error_rate = 0.1927710843373494

# %%
res = 0

i_0 = 1
res_0 = 0
res_0_1 = 0
res_0_2 = 0
res_0_3 = 0
res_0_4 = 0

i_1 = 1
res_1 = 0
res_1_1 = 0
res_1_2 = 0
res_1_3 = 0

i_2 = 1
res_2 = 0
res_2_1 = 0
res_2_2 = 0

i_3 = 1
res_3 = 0
res_3_1 = 0
res_3_2 = 0
res_3_3 = 0

i_4 = 1
res_4 = 0
res_4_1 = 0
res_4_2 = 0
res_4_3 = 0
res_4_4 = 0

for value in labels_dir_val:
    if value == 0:
        i_0 += 1
    elif value == 1:
        i_1 += 1
    elif value == 2:
        i_2 += 1
    elif value == 3:
        i_3 += 1
    elif value == 4:
        i_4 += 1

for i, value in enumerate(dir_preds):
    if value != labels_dir_val[i]:
        res += 1
        if labels_dir_val[i] == 0:    
            res_0 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_0_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_0_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_0_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_0_4 += 1
        elif labels_dir_val[i] == 1:
            res_1 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_1_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_1_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_1_3 += 1
        elif labels_dir_val[i] == 2:
            res_2 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_2_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_2_2 += 1
        elif labels_dir_val[i] == 3:
            res_3 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_3_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_3_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_3_3 += 1
        elif labels_dir_val[i] == 4:
            res_4 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_4_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_4_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_4_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_4_4 += 1

        
print("total error = " + str(res/i), "0_error = " + str(res_0/i_0), "1_error = " + str(res_1/i_1), "2_error = " + str(res_2/i_2), "3_error = " + str(res_3/i_3), "4_error = " + str(res_4/i_4), )
# Out:
# total error = 0.27710843373493976 0_error = 0.5 1_error = 0.0728476821192053 2_error = 0.6944444444444444 3_error = 0.0 4_error = 0.0

# %%
x = ['0','1','2','3','4']
plt.bar(x, height= [res_0/i_0, res_1/i_1, res_2/i_2, res_3/i_3, res_4/i_4])
plt.xticks(x, ['0','1','2','3','4']);
plt.title("Mean Errors by direction")
# Out:
# Text(0.5,1,'Mean Errors by direction')

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_0_1/res_0, res_0_2/res_0, res_0_3/res_0, res_0_4/res_0])
plt.xticks(x, ['1','2','3','4']);
plt.title("0 Errors")
# Out:
# Text(0.5,1,'0 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_1_1/res_1, res_1_2/res_1, res_1_3/res_1])
plt.xticks(x, ['0, 2','3', '4']);
plt.title("1 Errors")
# Out:
# Text(0.5,1,'1 Errors')

# %%
x = ['1','2']
plt.bar(x, height= [res_2_1/res_2, res_2_2/res_2])
plt.xticks(x, ['1, 3','0, 4']);
plt.title("2 Errors")
# Out:
# Text(0.5,1,'2 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
plt.xticks(x, ['2, 4','1', '0']);
plt.title("3 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-74-7793623322ad> in <module>()
#       1 x = ['1','2','3']
# ----> 2 plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
#       3 plt.xticks(x, ['2, 4','1', '0']);
#       4 plt.title("3 Errors")
#
# ZeroDivisionError: division by zero

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
plt.xticks(x, ['3','2','1','0']);
plt.title("4 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-75-3873ada9ae3b> in <module>()
#       1 x = ['1','2','3','4']
# ----> 2 plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
#       3 plt.xticks(x, ['3','2','1','0']);
#       4 plt.title("4 Errors")
#
# ZeroDivisionError: division by zero
