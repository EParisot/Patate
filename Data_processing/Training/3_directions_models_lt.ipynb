# %%
from os import listdir
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from PIL import Image
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import random
# Out:
# C:\Users\Rock_\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_photos(directory):
    images = []
    labels_speed = []
    labels_dir = []
    dir_list = listdir(directory)
    random.shuffle(dir_list)
    random.shuffle(dir_list)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename, target_size=(96, 160))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # get image id + labels
        value_dir = float(name.split('_')[1])
        value_speed = float(name.split('_')[0])
        labels_dir.append(value_dir)
        labels_speed.append(value_speed)
        images.append(image)
    return images, labels_speed, labels_dir

# %%
#dataset = "../../Pics/cleaned1"
#dataset = "../../Pics/mirrored1"
#dataset = "../../Pics/tagged2"
#dataset = "../../Pics/mirrored2"
#dataset = "../../Pics/testTrack"
#dataset = "../../Pics/test_noFE_mirrored"

#dataset = "../../Pics/Track/OldDataset_balanced"
#dataset = "../../Pics/Track/Datasets_Axionable/ironcar_pics"
#dataset = "../../Pics/Track/Mixed"
dataset = "../../Pics/Track/OldDataset_balanced_3"

#dataset = "../../Pics/BigOne"

# %%
# load images from both train and test groups
directory = '../../' + dataset
images, labels_speed, labels_dir = load_photos(directory)
nb_images = len(images)
print('Loaded Images and labels: %d' % nb_images)
# Out:
# Loaded Images and labels: 1699

# %%
#Normalise images
images = np.array(images)
images /= 255

# %%
#convert datas to dummyvalues
labels_speed = np.array(pd.get_dummies(labels_speed))
labels_dir = np.array(pd.get_dummies(labels_dir))

# %%
labels_speed[42], labels_dir[42], plt.imshow(images[42])
# Out:
# (array([1, 0], dtype=uint8),
#  array([0, 1, 0], dtype=uint8),
#  <matplotlib.image.AxesImage at 0x207593b9b70>)

# %%
from keras.models import Model, Sequential
from keras.layers import *
import keras.backend as K
import keras.optimizers as Optimizers

# %%
K.clear_session()
############################################################# Multitask Model 2

img_in = Input(shape=(96, 160, 3), name='img_in')
x = img_in

x = Convolution2D(8, (8,4), strides=(4,4), activation='relu')(x)
x = Convolution2D(8, (2,1), strides=(2,2), activation='relu')(x)
x = Convolution2D(8, (1,1), strides=(1,1), activation='relu')(x)

x = BatchNormalization()(x)

x = Flatten()(x)

x = Dense(8, activation='relu')(x)
x = Dropout(0.4)(x)

out_speed = Dense(2, activation='softmax')(x)
out_dir = Dense(3, activation='softmax')(x)

model = Model(inputs=[img_in], outputs=[out_speed, out_dir])
model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_in (InputLayer)             (None, 96, 160, 3)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 23, 40, 8)    776         img_in[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 11, 20, 8)    136         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 11, 20, 8)    72          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 11, 20, 8)    32          conv2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1760)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            14088       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            18          dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            27          dropout_1[0][0]
# ==================================================================================================
# Total params: 15,149
# Trainable params: 15,133
# Non-trainable params: 16
# __________________________________________________________________________________________________

# %%
h = model.fit(images, [labels_speed, labels_dir], batch_size=128, epochs=20, verbose=1, validation_split=0.3)
# Out:
# Train on 1189 samples, validate on 510 samples
# Epoch 1/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 1.0676 - dense_2_loss: 0.3294 - dense_3_loss: 0.7381 - dense_2_acc: 0.8469 - dense_3_acc: 0.6838 - val_loss: 1.0003 - val_dense_2_loss: 0.3197 - val_dense_3_loss: 0.6806 - val_dense_2_acc: 0.8569 - val_dense_3_acc: 0.7216
# Epoch 2/20
# 1189/1189 [==============================] - 5s 4ms/step - loss: 1.0560 - dense_2_loss: 0.3260 - dense_3_loss: 0.7300 - dense_2_acc: 0.8520 - dense_3_acc: 0.6812 - val_loss: 1.9048 - val_dense_2_loss: 0.6859 - val_dense_3_loss: 1.2189 - val_dense_2_acc: 0.7020 - val_dense_3_acc: 0.6353
# Epoch 3/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 1.0616 - dense_2_loss: 0.3234 - dense_3_loss: 0.7382 - dense_2_acc: 0.8478 - dense_3_acc: 0.6754 - val_loss: 1.0227 - val_dense_2_loss: 0.3262 - val_dense_3_loss: 0.6965 - val_dense_2_acc: 0.8510 - val_dense_3_acc: 0.7216
# Epoch 4/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.9752 - dense_2_loss: 0.3015 - dense_3_loss: 0.6738 - dense_2_acc: 0.8654 - dense_3_acc: 0.7056 - val_loss: 0.9881 - val_dense_2_loss: 0.3282 - val_dense_3_loss: 0.6599 - val_dense_2_acc: 0.8510 - val_dense_3_acc: 0.7196
# Epoch 5/20
# 1189/1189 [==============================] - 4s 4ms/step - loss: 0.9935 - dense_2_loss: 0.3271 - dense_3_loss: 0.6664 - dense_2_acc: 0.8486 - dense_3_acc: 0.6972 - val_loss: 1.0695 - val_dense_2_loss: 0.3786 - val_dense_3_loss: 0.6909 - val_dense_2_acc: 0.8431 - val_dense_3_acc: 0.7255
# Epoch 6/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 0.9649 - dense_2_loss: 0.3008 - dense_3_loss: 0.6641 - dense_2_acc: 0.8663 - dense_3_acc: 0.7040 - val_loss: 1.0404 - val_dense_2_loss: 0.3590 - val_dense_3_loss: 0.6814 - val_dense_2_acc: 0.8314 - val_dense_3_acc: 0.7392
# Epoch 7/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 0.9694 - dense_2_loss: 0.3115 - dense_3_loss: 0.6579 - dense_2_acc: 0.8612 - dense_3_acc: 0.7065 - val_loss: 0.9818 - val_dense_2_loss: 0.3252 - val_dense_3_loss: 0.6566 - val_dense_2_acc: 0.8647 - val_dense_3_acc: 0.7490
# Epoch 8/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 0.9340 - dense_2_loss: 0.2768 - dense_3_loss: 0.6572 - dense_2_acc: 0.8747 - dense_3_acc: 0.7115 - val_loss: 1.0281 - val_dense_2_loss: 0.3502 - val_dense_3_loss: 0.6778 - val_dense_2_acc: 0.8490 - val_dense_3_acc: 0.7314
# Epoch 9/20
# 1189/1189 [==============================] - 4s 4ms/step - loss: 0.9300 - dense_2_loss: 0.2840 - dense_3_loss: 0.6461 - dense_2_acc: 0.8915 - dense_3_acc: 0.7174 - val_loss: 1.1024 - val_dense_2_loss: 0.3650 - val_dense_3_loss: 0.7374 - val_dense_2_acc: 0.8431 - val_dense_3_acc: 0.7020
# Epoch 10/20
# 1189/1189 [==============================] - 5s 4ms/step - loss: 0.9493 - dense_2_loss: 0.2974 - dense_3_loss: 0.6519 - dense_2_acc: 0.8755 - dense_3_acc: 0.7124 - val_loss: 1.0233 - val_dense_2_loss: 0.3459 - val_dense_3_loss: 0.6774 - val_dense_2_acc: 0.8490 - val_dense_3_acc: 0.7451
# Epoch 11/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.8955 - dense_2_loss: 0.2710 - dense_3_loss: 0.6245 - dense_2_acc: 0.8806 - dense_3_acc: 0.7309 - val_loss: 0.9650 - val_dense_2_loss: 0.3259 - val_dense_3_loss: 0.6391 - val_dense_2_acc: 0.8667 - val_dense_3_acc: 0.7647
# Epoch 12/20
# 1189/1189 [==============================] - 3s 2ms/step - loss: 0.9054 - dense_2_loss: 0.2783 - dense_3_loss: 0.6271 - dense_2_acc: 0.8772 - dense_3_acc: 0.7292 - val_loss: 0.9728 - val_dense_2_loss: 0.3091 - val_dense_3_loss: 0.6637 - val_dense_2_acc: 0.8686 - val_dense_3_acc: 0.7235
# Epoch 13/20
# 1189/1189 [==============================] - 5s 4ms/step - loss: 0.8659 - dense_2_loss: 0.2609 - dense_3_loss: 0.6049 - dense_2_acc: 0.8915 - dense_3_acc: 0.7368 - val_loss: 1.0210 - val_dense_2_loss: 0.3843 - val_dense_3_loss: 0.6367 - val_dense_2_acc: 0.8255 - val_dense_3_acc: 0.7608
# Epoch 14/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.8658 - dense_2_loss: 0.2584 - dense_3_loss: 0.6074 - dense_2_acc: 0.9008 - dense_3_acc: 0.7208 - val_loss: 1.0106 - val_dense_2_loss: 0.3401 - val_dense_3_loss: 0.6705 - val_dense_2_acc: 0.8529 - val_dense_3_acc: 0.7314
# Epoch 15/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.8456 - dense_2_loss: 0.2515 - dense_3_loss: 0.5942 - dense_2_acc: 0.8915 - dense_3_acc: 0.7527 - val_loss: 1.1082 - val_dense_2_loss: 0.4207 - val_dense_3_loss: 0.6875 - val_dense_2_acc: 0.8353 - val_dense_3_acc: 0.7412
# Epoch 16/20
# 1189/1189 [==============================] - 5s 4ms/step - loss: 0.8499 - dense_2_loss: 0.2643 - dense_3_loss: 0.5856 - dense_2_acc: 0.8814 - dense_3_acc: 0.7443 - val_loss: 0.9883 - val_dense_2_loss: 0.3229 - val_dense_3_loss: 0.6655 - val_dense_2_acc: 0.8608 - val_dense_3_acc: 0.7314
# Epoch 17/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.8284 - dense_2_loss: 0.2459 - dense_3_loss: 0.5825 - dense_2_acc: 0.9033 - dense_3_acc: 0.7494 - val_loss: 1.0127 - val_dense_2_loss: 0.3308 - val_dense_3_loss: 0.6818 - val_dense_2_acc: 0.8647 - val_dense_3_acc: 0.7294
# Epoch 18/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.8321 - dense_2_loss: 0.2490 - dense_3_loss: 0.5832 - dense_2_acc: 0.8966 - dense_3_acc: 0.7527 - val_loss: 1.1196 - val_dense_2_loss: 0.4011 - val_dense_3_loss: 0.7185 - val_dense_2_acc: 0.8431 - val_dense_3_acc: 0.7039
# Epoch 19/20
# 1189/1189 [==============================] - 5s 4ms/step - loss: 0.8690 - dense_2_loss: 0.2726 - dense_3_loss: 0.5964 - dense_2_acc: 0.8755 - dense_3_acc: 0.7292 - val_loss: 1.2326 - val_dense_2_loss: 0.4391 - val_dense_3_loss: 0.7935 - val_dense_2_acc: 0.8039 - val_dense_3_acc: 0.7216
# Epoch 20/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 0.7910 - dense_2_loss: 0.2550 - dense_3_loss: 0.5360 - dense_2_acc: 0.8898 - dense_3_acc: 0.7696 - val_loss: 0.9779 - val_dense_2_loss: 0.3279 - val_dense_3_loss: 0.6500 - val_dense_2_acc: 0.8627 - val_dense_3_acc: 0.7471

# %%
#print History graph
historydf = pd.DataFrame(h.history, index=h.epoch)
historydf.plot(ylim=(0,1))

# %%
model.save('model_multi_race3.h5')

# %%
#######################  VALIDATION

#dataset = "../../Pics/cleaned1"
#dataset = "../../Pics/mirrored1"
#dataset = "../../Pics/tagged2"
#dataset = "../../Pics/mirrored2"
#dataset = "../../Pics/testTrack"
#dataset = "../../Pics/test_noFE_mirrored"

#dataset = "../../Pics/Track/OldDataset_balanced"
#dataset = "../../Pics/Track/Datasets_Axionable/ironcar_pics"
#dataset = "../../Pics/Track/Mixed"
dataset = "../../Pics/Track/OldDataset_balanced_3"

#dataset = "../../Pics/BigOne"

# %%
def load_photos_val(directory):
    images = []
    labels_speed = []
    labels_dir = []
    dir_list = listdir(directory)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename, target_size=(96, 160))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # get image id + labels
        value_dir = float(name.split('_')[1])
        value_speed = float(name.split('_')[0])
        labels_dir.append(value_dir)
        labels_speed.append(value_speed)
        images.append(image)
    return images, labels_speed, labels_dir

# %%
# load images from both train and test groups
directory = '../../' + dataset
images_val, labels_speed_val, labels_dir_val = load_photos(directory)
nb_images = len(images_val)
print('Loaded Images and labels: %d' % nb_images)
# Out:
# Loaded Images and labels: 1699

# %%
images_val = np.array(images_val)
images_val /= 255

# %%
# Get predictions
all_preds = model.predict(images_val)

speed_preds = []
for elem in all_preds[0]:
    speed_preds.append(np.argmax(elem))
    
dir_preds = []
for elem in all_preds[1]:
    dir_preds.append(np.argmax(elem))

# %%
res = 0
for i, value in enumerate(speed_preds):
    if value != labels_speed_val[i]:
        res += 1
print("error_rate = " + str(res/i))
# Out:
# error_rate = 0.07714958775029446

# %%
res = 0

i_0 = 1
res_0 = 0
res_0_1 = 0
res_0_2 = 0
res_0_3 = 0
res_0_4 = 0

i_1 = 1
res_1 = 0
res_1_1 = 0
res_1_2 = 0
res_1_3 = 0

i_2 = 1
res_2 = 0
res_2_1 = 0
res_2_2 = 0

i_3 = 1
res_3 = 0
res_3_1 = 0
res_3_2 = 0
res_3_3 = 0

i_4 = 1
res_4 = 0
res_4_1 = 0
res_4_2 = 0
res_4_3 = 0
res_4_4 = 0

for value in labels_dir_val:
    if value == 0:
        i_0 += 1
    elif value == 1:
        i_1 += 1
    elif value == 2:
        i_2 += 1
    elif value == 3:
        i_3 += 1
    elif value == 4:
        i_4 += 1

for i, value in enumerate(dir_preds):
    if value != labels_dir_val[i]:
        res += 1
        if labels_dir_val[i] == 0:    
            res_0 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_0_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_0_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_0_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_0_4 += 1
        elif labels_dir_val[i] == 1:
            res_1 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_1_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_1_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_1_3 += 1
        elif labels_dir_val[i] == 2:
            res_2 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_2_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_2_2 += 1
        elif labels_dir_val[i] == 3:
            res_3 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_3_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_3_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_3_3 += 1
        elif labels_dir_val[i] == 4:
            res_4 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_4_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_4_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_4_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_4_4 += 1

        
print("total error = " + str(res/i), "0_error = " + str(res_0/i_0), "1_error = " + str(res_1/i_1), "2_error = " + str(res_2/i_2), "3_error = " + str(res_3/i_3), "4_error = " + str(res_4/i_4), )
# Out:
# total error = 0.16313309776207302 0_error = 0.2942477876106195 1_error = 0.06499429874572406 2_error = 0.23324396782841822 3_error = 0.0 4_error = 0.0

# %%
x = ['0','1','2','3','4']
plt.bar(x, height= [res_0/i_0, res_1/i_1, res_2/i_2, res_3/i_3, res_4/i_4])
plt.xticks(x, ['0','1','2','3','4']);
plt.title("Mean Errors by direction")
# Out:
# Text(0.5,1,'Mean Errors by direction')

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_0_1/res_0, res_0_2/res_0, res_0_3/res_0, res_0_4/res_0])
plt.xticks(x, ['1','2','3','4']);
plt.title("0 Errors")
# Out:
# Text(0.5,1,'0 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_1_1/res_1, res_1_2/res_1, res_1_3/res_1])
plt.xticks(x, ['0, 2','3', '4']);
plt.title("1 Errors")
# Out:
# Text(0.5,1,'1 Errors')

# %%
x = ['1','2']
plt.bar(x, height= [res_2_1/res_2, res_2_2/res_2])
plt.xticks(x, ['1, 3','0, 4']);
plt.title("2 Errors")
# Out:
# Text(0.5,1,'2 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
plt.xticks(x, ['2, 4','1', '0']);
plt.title("3 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-26-7793623322ad> in <module>()
#       1 x = ['1','2','3']
# ----> 2 plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
#       3 plt.xticks(x, ['2, 4','1', '0']);
#       4 plt.title("3 Errors")
#
# ZeroDivisionError: division by zero

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
plt.xticks(x, ['3','2','1','0']);
plt.title("4 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-27-3873ada9ae3b> in <module>()
#       1 x = ['1','2','3','4']
# ----> 2 plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
#       3 plt.xticks(x, ['3','2','1','0']);
#       4 plt.title("4 Errors")
#
# ZeroDivisionError: division by zero
