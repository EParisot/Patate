# %%
from os import listdir
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from PIL import Image
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import random
# Out:
# C:\Users\Rock_\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_photos(directory):
    images = []
    labels_speed = []
    labels_dir = []
    dir_list = listdir(directory)
    #random.shuffle(dir_list)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename, target_size=(96, 160))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # get image id + labels
        value_dir = float(name.split('_')[1])
        value_speed = float(name.split('_')[0])
        labels_dir.append(value_dir)
        labels_speed.append(value_speed)
        images.append(image)
    return images, labels_speed, labels_dir

# %%
#dataset = "../../Pics/TestTrack/cleaned1"
#dataset = "../../Pics/TestTrack/mirrored1"
#dataset = "../../Pics/TestTrack/tagged2"
#dataset = "../../Pics/TestTrack/mirrored2"
#dataset = "../../Pics/TestTrack/test_noFE_mirrored"

#dataset = "../../Pics/RaceTrack/OldDataset_balanced"
#dataset = "../../Pics/RaceTrack/Datasets_Axionable/ironcar_pics"
#dataset = "../../Pics/RaceTrack/Mixed"
dataset = "../../Pics/RaceTrack/OldDataset_3"

# %%
# load images from both train and test groups
directory = '../../'+dataset+'/Train'
images, labels_speed, labels_dir = load_photos(directory)
nb_images = len(images)
print('Loaded Images and labels for training: %d' % nb_images)
directory = '../../'+dataset+'/Val'
images_val, labels_speed_val, labels_dir_val = load_photos(directory)
nb_images_val = len(images_val)
print('Loaded Images and labels for validation: %d' % nb_images_val)
# Out:
# Loaded Images and labels for training: 1210
# Loaded Images and labels for validation: 250

# %%
#Normalise images
images = np.array(images)
images /= 255

# %%
#convert datas to dummyvalues
labels_speed = np.array(pd.get_dummies(labels_speed))
labels_dir = np.array(pd.get_dummies(labels_dir))

# %%
labels_speed[42], labels_dir[42], plt.imshow(images[42])
# Out:
# (array([1, 0], dtype=uint8),
#  array([1, 0, 0], dtype=uint8),
#  <matplotlib.image.AxesImage at 0x1c4d9b74a90>)

# %%
from keras.models import Model, Sequential
from keras.layers import *
import keras.backend as K
import keras.optimizers as Optimizers

# %%
K.clear_session()
############################################################# Multitask Model 1

img_in = Input(shape=(96, 160, 3), name='img_in')
x = img_in

x = Convolution2D(2, (6,4), strides=(2,2), activation='relu')(x)
x = Convolution2D(4, (4,2), strides=(2,1), activation='relu')(x)
x = BatchNormalization()(x)

x = Flatten()(x)

x = Dense(8, activation='relu')(x)
x = Dropout(0.4)(x)

out_speed = Dense(2, activation='softmax')(x)
out_dir = Dense(3, activation='softmax')(x)

model = Model(inputs=[img_in], outputs=[out_speed, out_dir])
model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_in (InputLayer)             (None, 96, 160, 3)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 46, 79, 2)    146         img_in[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 22, 78, 4)    68          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 22, 78, 4)    16          conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 6864)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            54920       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            18          dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            27          dropout_1[0][0]
# ==================================================================================================
# Total params: 55,195
# Trainable params: 55,187
# Non-trainable params: 8
# __________________________________________________________________________________________________

# %%
h = model.fit(images, [labels_speed, labels_dir], batch_size=128, epochs=50, verbose=1)
# Out:
# Epoch 1/100
# 1210/1210 [==============================] - 9s 7ms/step - loss: 1.7109 - dense_2_loss: 0.6609 - dense_3_loss: 1.0500 - dense_2_acc: 0.6529 - dense_3_acc: 0.5140
# Epoch 2/100
# 1210/1210 [==============================] - 8s 6ms/step - loss: 1.5293 - dense_2_loss: 0.5584 - dense_3_loss: 0.9709 - dense_2_acc: 0.7521 - dense_3_acc: 0.5843
# Epoch 3/100
# 1210/1210 [==============================] - 7s 6ms/step - loss: 1.4357 - dense_2_loss: 0.5452 - dense_3_loss: 0.8904 - dense_2_acc: 0.7793 - dense_3_acc: 0.5983
# Epoch 4/100
# 1210/1210 [==============================] - 8s 7ms/step - loss: 1.3502 - dense_2_loss: 0.4949 - dense_3_loss: 0.8552 - dense_2_acc: 0.7934 - dense_3_acc: 0.6041
# Epoch 5/100
# 1210/1210 [==============================] - 7s 6ms/step - loss: 1.2419 - dense_2_loss: 0.4485 - dense_3_loss: 0.7934 - dense_2_acc: 0.8190 - dense_3_acc: 0.6388
# Epoch 6/100
# 1210/1210 [==============================] - 6s 5ms/step - loss: 1.1027 - dense_2_loss: 0.3855 - dense_3_loss: 0.7172 - dense_2_acc: 0.8529 - dense_3_acc: 0.6793
# Epoch 7/100
# 1210/1210 [==============================] - 6s 5ms/step - loss: 1.0029 - dense_2_loss: 0.3572 - dense_3_loss: 0.6457 - dense_2_acc: 0.8463 - dense_3_acc: 0.7132
# Epoch 8/100
# 1210/1210 [==============================] - 14s 12ms/step - loss: 0.9624 - dense_2_loss: 0.3422 - dense_3_loss: 0.6202 - dense_2_acc: 0.8570 - dense_3_acc: 0.7050
# Epoch 9/100
# 1210/1210 [==============================] - 19s 15ms/step - loss: 0.8674 - dense_2_loss: 0.3004 - dense_3_loss: 0.5670 - dense_2_acc: 0.8711 - dense_3_acc: 0.7364
# Epoch 10/100
# 1210/1210 [==============================] - 20s 17ms/step - loss: 0.8147 - dense_2_loss: 0.2821 - dense_3_loss: 0.5326 - dense_2_acc: 0.8934 - dense_3_acc: 0.7521
# Epoch 11/100
# 1210/1210 [==============================] - 19s 16ms/step - loss: 0.7423 - dense_2_loss: 0.2533 - dense_3_loss: 0.4890 - dense_2_acc: 0.9017 - dense_3_acc: 0.7620
# Epoch 12/100
# 1210/1210 [==============================] - 23s 19ms/step - loss: 0.7249 - dense_2_loss: 0.2518 - dense_3_loss: 0.4731 - dense_2_acc: 0.9008 - dense_3_acc: 0.7686
# Epoch 13/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.6691 - dense_2_loss: 0.2240 - dense_3_loss: 0.4451 - dense_2_acc: 0.9083 - dense_3_acc: 0.7818
# Epoch 14/100
# 1210/1210 [==============================] - 26s 21ms/step - loss: 0.6342 - dense_2_loss: 0.2276 - dense_3_loss: 0.4066 - dense_2_acc: 0.8983 - dense_3_acc: 0.8074
# Epoch 15/100
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.5966 - dense_2_loss: 0.2073 - dense_3_loss: 0.3894 - dense_2_acc: 0.9190 - dense_3_acc: 0.8132
# Epoch 16/100
# 1210/1210 [==============================] - 31s 25ms/step - loss: 0.5921 - dense_2_loss: 0.1938 - dense_3_loss: 0.3983 - dense_2_acc: 0.9165 - dense_3_acc: 0.8000
# Epoch 17/100
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.5777 - dense_2_loss: 0.2000 - dense_3_loss: 0.3777 - dense_2_acc: 0.9198 - dense_3_acc: 0.8033
# Epoch 18/100
# 1210/1210 [==============================] - 30s 24ms/step - loss: 0.5478 - dense_2_loss: 0.1624 - dense_3_loss: 0.3854 - dense_2_acc: 0.9413 - dense_3_acc: 0.8083
# Epoch 19/100
# 1210/1210 [==============================] - 28s 23ms/step - loss: 0.5212 - dense_2_loss: 0.1710 - dense_3_loss: 0.3502 - dense_2_acc: 0.9298 - dense_3_acc: 0.8174
# Epoch 20/100
# 1210/1210 [==============================] - 28s 23ms/step - loss: 0.5561 - dense_2_loss: 0.1860 - dense_3_loss: 0.3701 - dense_2_acc: 0.9264 - dense_3_acc: 0.8083
# Epoch 21/100
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.5047 - dense_2_loss: 0.1602 - dense_3_loss: 0.3446 - dense_2_acc: 0.9273 - dense_3_acc: 0.8281
# Epoch 22/100
# 1210/1210 [==============================] - 28s 23ms/step - loss: 0.4976 - dense_2_loss: 0.1677 - dense_3_loss: 0.3299 - dense_2_acc: 0.9289 - dense_3_acc: 0.8322
# Epoch 23/100
# 1210/1210 [==============================] - 32s 26ms/step - loss: 0.4679 - dense_2_loss: 0.1536 - dense_3_loss: 0.3143 - dense_2_acc: 0.9347 - dense_3_acc: 0.8471
# Epoch 24/100
# 1210/1210 [==============================] - 28s 23ms/step - loss: 0.4569 - dense_2_loss: 0.1537 - dense_3_loss: 0.3031 - dense_2_acc: 0.9380 - dense_3_acc: 0.8455
# Epoch 25/100
# 1210/1210 [==============================] - 28s 24ms/step - loss: 0.4322 - dense_2_loss: 0.1408 - dense_3_loss: 0.2914 - dense_2_acc: 0.9405 - dense_3_acc: 0.8587
# Epoch 26/100
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.4488 - dense_2_loss: 0.1462 - dense_3_loss: 0.3027 - dense_2_acc: 0.9380 - dense_3_acc: 0.8479
# Epoch 27/100
# 1210/1210 [==============================] - 28s 23ms/step - loss: 0.4670 - dense_2_loss: 0.1513 - dense_3_loss: 0.3157 - dense_2_acc: 0.9364 - dense_3_acc: 0.8446
# Epoch 28/100
# 1210/1210 [==============================] - 30s 25ms/step - loss: 0.4330 - dense_2_loss: 0.1368 - dense_3_loss: 0.2961 - dense_2_acc: 0.9430 - dense_3_acc: 0.8587
# Epoch 29/100
# 1210/1210 [==============================] - 26s 22ms/step - loss: 0.4408 - dense_2_loss: 0.1322 - dense_3_loss: 0.3086 - dense_2_acc: 0.9496 - dense_3_acc: 0.8405
# Epoch 30/100
# 1210/1210 [==============================] - 27s 22ms/step - loss: 0.4286 - dense_2_loss: 0.1370 - dense_3_loss: 0.2916 - dense_2_acc: 0.9355 - dense_3_acc: 0.8463
# Epoch 31/100
# 1210/1210 [==============================] - 24s 19ms/step - loss: 0.4112 - dense_2_loss: 0.1270 - dense_3_loss: 0.2842 - dense_2_acc: 0.9521 - dense_3_acc: 0.8479
# Epoch 32/100
# 1210/1210 [==============================] - 26s 21ms/step - loss: 0.3992 - dense_2_loss: 0.1297 - dense_3_loss: 0.2695 - dense_2_acc: 0.9405 - dense_3_acc: 0.8603
# Epoch 33/100
# 1210/1210 [==============================] - 26s 21ms/step - loss: 0.4132 - dense_2_loss: 0.1256 - dense_3_loss: 0.2876 - dense_2_acc: 0.9603 - dense_3_acc: 0.8479
# Epoch 34/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.4249 - dense_2_loss: 0.1383 - dense_3_loss: 0.2865 - dense_2_acc: 0.9355 - dense_3_acc: 0.8521
# Epoch 35/100
# 1210/1210 [==============================] - 25s 21ms/step - loss: 0.3924 - dense_2_loss: 0.1266 - dense_3_loss: 0.2657 - dense_2_acc: 0.9430 - dense_3_acc: 0.8587
# Epoch 36/100
# 1210/1210 [==============================] - 24s 19ms/step - loss: 0.3845 - dense_2_loss: 0.1230 - dense_3_loss: 0.2615 - dense_2_acc: 0.9554 - dense_3_acc: 0.8744
# Epoch 37/100
# 1210/1210 [==============================] - 26s 22ms/step - loss: 0.3867 - dense_2_loss: 0.1189 - dense_3_loss: 0.2678 - dense_2_acc: 0.9554 - dense_3_acc: 0.8595
# Epoch 38/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.3801 - dense_2_loss: 0.1191 - dense_3_loss: 0.2610 - dense_2_acc: 0.9562 - dense_3_acc: 0.8521
# Epoch 39/100
# 1210/1210 [==============================] - 26s 22ms/step - loss: 0.3722 - dense_2_loss: 0.1036 - dense_3_loss: 0.2686 - dense_2_acc: 0.9736 - dense_3_acc: 0.8455
# Epoch 40/100
# 1210/1210 [==============================] - 23s 19ms/step - loss: 0.3734 - dense_2_loss: 0.1059 - dense_3_loss: 0.2676 - dense_2_acc: 0.9645 - dense_3_acc: 0.8496
# Epoch 41/100
# 1210/1210 [==============================] - 25s 21ms/step - loss: 0.3640 - dense_2_loss: 0.1055 - dense_3_loss: 0.2584 - dense_2_acc: 0.9686 - dense_3_acc: 0.8595
# Epoch 42/100
# 1210/1210 [==============================] - 25s 21ms/step - loss: 0.3530 - dense_2_loss: 0.1013 - dense_3_loss: 0.2518 - dense_2_acc: 0.9645 - dense_3_acc: 0.8612
# Epoch 43/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.3794 - dense_2_loss: 0.1102 - dense_3_loss: 0.2692 - dense_2_acc: 0.9612 - dense_3_acc: 0.8554
# Epoch 44/100
# 1210/1210 [==============================] - 22s 18ms/step - loss: 0.3567 - dense_2_loss: 0.1063 - dense_3_loss: 0.2504 - dense_2_acc: 0.9645 - dense_3_acc: 0.8603
# Epoch 45/100
# 1210/1210 [==============================] - 23s 19ms/step - loss: 0.3484 - dense_2_loss: 0.0947 - dense_3_loss: 0.2537 - dense_2_acc: 0.9686 - dense_3_acc: 0.8570
# Epoch 46/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.3517 - dense_2_loss: 0.1084 - dense_3_loss: 0.2434 - dense_2_acc: 0.9579 - dense_3_acc: 0.8727
# Epoch 47/100
# 1210/1210 [==============================] - 26s 21ms/step - loss: 0.3665 - dense_2_loss: 0.1069 - dense_3_loss: 0.2596 - dense_2_acc: 0.9620 - dense_3_acc: 0.8595
# Epoch 48/100
# 1210/1210 [==============================] - 23s 19ms/step - loss: 0.3351 - dense_2_loss: 0.0969 - dense_3_loss: 0.2382 - dense_2_acc: 0.9694 - dense_3_acc: 0.8702
# Epoch 49/100
# 1210/1210 [==============================] - 26s 22ms/step - loss: 0.3600 - dense_2_loss: 0.1134 - dense_3_loss: 0.2466 - dense_2_acc: 0.9587 - dense_3_acc: 0.8719
# Epoch 50/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.3276 - dense_2_loss: 0.0944 - dense_3_loss: 0.2332 - dense_2_acc: 0.9736 - dense_3_acc: 0.8727
# Epoch 51/100
# 1210/1210 [==============================] - 25s 21ms/step - loss: 0.3287 - dense_2_loss: 0.0890 - dense_3_loss: 0.2397 - dense_2_acc: 0.9711 - dense_3_acc: 0.8628
# Epoch 52/100
# 1210/1210 [==============================] - 26s 22ms/step - loss: 0.3399 - dense_2_loss: 0.1019 - dense_3_loss: 0.2380 - dense_2_acc: 0.9661 - dense_3_acc: 0.8769
# Epoch 53/100
# 1210/1210 [==============================] - 24s 19ms/step - loss: 0.3161 - dense_2_loss: 0.0957 - dense_3_loss: 0.2204 - dense_2_acc: 0.9686 - dense_3_acc: 0.8826
# Epoch 54/100
# 1210/1210 [==============================] - 25s 21ms/step - loss: 0.3154 - dense_2_loss: 0.0823 - dense_3_loss: 0.2331 - dense_2_acc: 0.9719 - dense_3_acc: 0.8744
# Epoch 55/100
# 1210/1210 [==============================] - 24s 20ms/step - loss: 0.3474 - dense_2_loss: 0.1017 - dense_3_loss: 0.2457 - dense_2_acc: 0.9669 - dense_3_acc: 0.8603
# Epoch 56/100
#  384/1210 [========>.....................] - ETA: 16s - loss: 0.3716 - dense_2_loss: 0.1084 - dense_3_loss: 0.2632 - dense_2_acc: 0.9609 - dense_3_acc: 0.8490
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-91ea1bf3b830> in <module>()
# ----> 1 h = model.fit(images, [labels_speed, labels_dir], batch_size=128, epochs=100, verbose=1)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
#print History graph
historydf = pd.DataFrame(h.history, index=h.epoch)
historydf.plot(ylim=(0,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7b1b9dd0cdb2> in <module>()
#       1 #print History graph
# ----> 2 historydf = pd.DataFrame(h.history, index=h.epoch)
#       3 historydf.plot(ylim=(0,1))
#
# NameError: name 'h' is not defined

# %%
model.save('model_multi3_test.h5')

# %%
#######################  VALIDATION

# %%
from keras.models import load_model
model = load_model("../../model_multi_race3.h5")

# %%
images_val = np.array(images_val)
images_val /= 255

# %%
# Get predictions
all_preds = model.predict(images_val)

speed_preds = []
for elem in all_preds[0]:
    speed_preds.append(np.argmax(elem))
    
dir_preds = []
for elem in all_preds[1]:
    dir_preds.append(np.argmax(elem))

# %%
res = 0
for i, value in enumerate(speed_preds):
    if value != labels_speed_val[i]:
        res += 1
print("error_rate = " + str(res/i))
# Out:
# error_rate = 0.10441767068273092

# %%
res = 0

i_0 = 1
res_0 = 0
res_0_1 = 0
res_0_2 = 0
res_0_3 = 0
res_0_4 = 0

i_1 = 1
res_1 = 0
res_1_1 = 0
res_1_2 = 0
res_1_3 = 0

i_2 = 1
res_2 = 0
res_2_1 = 0
res_2_2 = 0

i_3 = 1
res_3 = 0
res_3_1 = 0
res_3_2 = 0
res_3_3 = 0

i_4 = 1
res_4 = 0
res_4_1 = 0
res_4_2 = 0
res_4_3 = 0
res_4_4 = 0

for value in labels_dir_val:
    if value == 0:
        i_0 += 1
    elif value == 1:
        i_1 += 1
    elif value == 2:
        i_2 += 1
    elif value == 3:
        i_3 += 1
    elif value == 4:
        i_4 += 1

for i, value in enumerate(dir_preds):
    if value != labels_dir_val[i]:
        res += 1
        if labels_dir_val[i] == 0:    
            res_0 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_0_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_0_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_0_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_0_4 += 1
        elif labels_dir_val[i] == 1:
            res_1 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_1_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_1_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_1_3 += 1
        elif labels_dir_val[i] == 2:
            res_2 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_2_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_2_2 += 1
        elif labels_dir_val[i] == 3:
            res_3 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_3_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_3_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_3_3 += 1
        elif labels_dir_val[i] == 4:
            res_4 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_4_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_4_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_4_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_4_4 += 1

        
print("total error = " + str(res/i), "0_error = " + str(res_0/i_0), "1_error = " + str(res_1/i_1), "2_error = " + str(res_2/i_2), "3_error = " + str(res_3/i_3), "4_error = " + str(res_4/i_4), )
# Out:
# total error = 0.17269076305220885 0_error = 0.3181818181818182 1_error = 0.059602649006622516 2_error = 0.3611111111111111 3_error = 0.0 4_error = 0.0

# %%
x = ['0','1','2','3','4']
plt.bar(x, height= [res_0/i_0, res_1/i_1, res_2/i_2, res_3/i_3, res_4/i_4])
plt.xticks(x, ['0','1','2','3','4']);
plt.title("Mean Errors by direction")
# Out:
# Text(0.5,1,'Mean Errors by direction')

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_0_1/res_0, res_0_2/res_0, res_0_3/res_0, res_0_4/res_0])
plt.xticks(x, ['1','2','3','4']);
plt.title("0 Errors")
# Out:
# Text(0.5,1,'0 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_1_1/res_1, res_1_2/res_1, res_1_3/res_1])
plt.xticks(x, ['0, 2','3', '4']);
plt.title("1 Errors")
# Out:
# Text(0.5,1,'1 Errors')

# %%
x = ['1','2']
plt.bar(x, height= [res_2_1/res_2, res_2_2/res_2])
plt.xticks(x, ['1, 3','0, 4']);
plt.title("2 Errors")
# Out:
# Text(0.5,1,'2 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
plt.xticks(x, ['2, 4','1', '0']);
plt.title("3 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-28-7793623322ad> in <module>()
#       1 x = ['1','2','3']
# ----> 2 plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
#       3 plt.xticks(x, ['2, 4','1', '0']);
#       4 plt.title("3 Errors")
#
# ZeroDivisionError: division by zero

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
plt.xticks(x, ['3','2','1','0']);
plt.title("4 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-29-3873ada9ae3b> in <module>()
#       1 x = ['1','2','3','4']
# ----> 2 plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
#       3 plt.xticks(x, ['3','2','1','0']);
#       4 plt.title("4 Errors")
#
# ZeroDivisionError: division by zero
