# %%
from os import listdir
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from PIL import Image
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import random
# Out:
# C:\Users\Rock_\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_photos(directory):
    images = []
    labels_speed = []
    labels_dir = []
    dir_list = listdir(directory)
    random.shuffle(dir_list)
    random.shuffle(dir_list)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename, target_size=(96, 160))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # get image id + labels
        value_dir = float(name.split('_')[1])
        value_speed = float(name.split('_')[0])
        labels_dir.append(value_dir)
        labels_speed.append(value_speed)
        images.append(image)
    return images, labels_speed, labels_dir

# %%
#dataset = "../../Pics/cleaned1"
#dataset = "../../Pics/mirrored1"
#dataset = "../../Pics/tagged2"
#dataset = "../../Pics/mirrored2"
#dataset = "../../Pics/testTrack"
dataset = "../../Pics/test_noFE_mirrored_3"

#dataset = "../../Pics/Track/OldDataset_balanced"
#dataset = "../../Pics/Track/Datasets_Axionable/ironcar_pics"
#dataset = "../../Pics/Track/Mixed"

#dataset = "../../Pics/BigOne"

# %%
# load images from both train and test groups
directory = '../../' + dataset
images, labels_speed, labels_dir = load_photos(directory)
nb_images = len(images)
print('Loaded Images and labels: %d' % nb_images)
# Out:
# Loaded Images and labels: 5180

# %%
#Normalise images
images = np.array(images)
images /= 255

# %%
#convert datas to dummyvalues
labels_speed = np.array(pd.get_dummies(labels_speed))
labels_dir = np.array(pd.get_dummies(labels_dir))

# %%
labels_speed[42], labels_dir[42], plt.imshow(images[42])
# Out:
# (array([1, 0], dtype=uint8),
#  array([0, 0, 1], dtype=uint8),
#  <matplotlib.image.AxesImage at 0x2733e2f7a90>)

# %%
from keras.models import Model, Sequential
from keras.layers import *
import keras.backend as K
import keras.optimizers as Optimizers

# %%
K.clear_session()
############################################################# Multitask Model 1

img_in = Input(shape=(96, 160, 3), name='img_in')
x = img_in

x = Convolution2D(2, (6,4), strides=(2,2), activation='relu')(x)
x = Convolution2D(4, (4,2), strides=(2,1), activation='relu')(x)
x = BatchNormalization()(x)

x = Flatten()(x)

x = Dense(8, activation='relu')(x)
x = Dropout(0.4)(x)

out_speed = Dense(2, activation='softmax')(x)
out_dir = Dense(3, activation='softmax')(x)

model = Model(inputs=[img_in], outputs=[out_speed, out_dir])
model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_in (InputLayer)             (None, 96, 160, 3)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 46, 79, 2)    146         img_in[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 22, 78, 4)    68          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 22, 78, 4)    16          conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 6864)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            27460       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            10          dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            15          dropout_1[0][0]
# ==================================================================================================
# Total params: 27,715
# Trainable params: 27,707
# Non-trainable params: 8
# __________________________________________________________________________________________________

# %%
h = model.fit(images, [labels_speed, labels_dir], batch_size=128, epochs=20, verbose=1, validation_split=0.3)
# Out:
# Train on 3625 samples, validate on 1555 samples
# Epoch 1/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 1.6290 - dense_2_loss: 0.6266 - dense_3_loss: 1.0023 - dense_2_acc: 0.7426 - dense_3_acc: 0.4874 - val_loss: 1.3676 - val_dense_2_loss: 0.4957 - val_dense_3_loss: 0.8718 - val_dense_2_acc: 0.7871 - val_dense_3_acc: 0.5486
# Epoch 2/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 1.3552 - dense_2_loss: 0.5321 - dense_3_loss: 0.8231 - dense_2_acc: 0.7721 - dense_3_acc: 0.5870 - val_loss: 4.5032 - val_dense_2_loss: 0.4152 - val_dense_3_loss: 4.0880 - val_dense_2_acc: 0.7859 - val_dense_3_acc: 0.3582
# Epoch 3/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 1.2545 - dense_2_loss: 0.4796 - dense_3_loss: 0.7748 - dense_2_acc: 0.7754 - dense_3_acc: 0.6022 - val_loss: 1.2049 - val_dense_2_loss: 0.3589 - val_dense_3_loss: 0.8460 - val_dense_2_acc: 0.7884 - val_dense_3_acc: 0.6000
# Epoch 4/20
# 3625/3625 [==============================] - 22s 6ms/step - loss: 1.1298 - dense_2_loss: 0.4215 - dense_3_loss: 0.7082 - dense_2_acc: 0.7912 - dense_3_acc: 0.6105 - val_loss: 1.8597 - val_dense_2_loss: 0.3329 - val_dense_3_loss: 1.5268 - val_dense_2_acc: 0.7897 - val_dense_3_acc: 0.3910
# Epoch 5/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 1.0315 - dense_2_loss: 0.3694 - dense_3_loss: 0.6622 - dense_2_acc: 0.8339 - dense_3_acc: 0.6328 - val_loss: 0.9603 - val_dense_2_loss: 0.3691 - val_dense_3_loss: 0.5912 - val_dense_2_acc: 0.8823 - val_dense_3_acc: 0.7576
# Epoch 6/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 0.9428 - dense_2_loss: 0.3252 - dense_3_loss: 0.6176 - dense_2_acc: 0.8483 - dense_3_acc: 0.6541 - val_loss: 2.0110 - val_dense_2_loss: 0.3191 - val_dense_3_loss: 1.6920 - val_dense_2_acc: 0.8096 - val_dense_3_acc: 0.4367
# Epoch 7/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 0.8326 - dense_2_loss: 0.2736 - dense_3_loss: 0.5590 - dense_2_acc: 0.8588 - dense_3_acc: 0.6797 - val_loss: 0.7804 - val_dense_2_loss: 0.2113 - val_dense_3_loss: 0.5692 - val_dense_2_acc: 0.9312 - val_dense_3_acc: 0.7518
# Epoch 8/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 0.7937 - dense_2_loss: 0.2562 - dense_3_loss: 0.5375 - dense_2_acc: 0.8566 - dense_3_acc: 0.7123 - val_loss: 0.6815 - val_dense_2_loss: 0.2305 - val_dense_3_loss: 0.4510 - val_dense_2_acc: 0.9203 - val_dense_3_acc: 0.8328
# Epoch 9/20
# 3625/3625 [==============================] - 25s 7ms/step - loss: 0.7514 - dense_2_loss: 0.2432 - dense_3_loss: 0.5082 - dense_2_acc: 0.8532 - dense_3_acc: 0.7600 - val_loss: 0.6520 - val_dense_2_loss: 0.2008 - val_dense_3_loss: 0.4511 - val_dense_2_acc: 0.9460 - val_dense_3_acc: 0.8257
# Epoch 10/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 0.7444 - dense_2_loss: 0.2346 - dense_3_loss: 0.5098 - dense_2_acc: 0.8590 - dense_3_acc: 0.7639 - val_loss: 1.3308 - val_dense_2_loss: 0.3031 - val_dense_3_loss: 1.0277 - val_dense_2_acc: 0.8772 - val_dense_3_acc: 0.6643
# Epoch 11/20
# 3625/3625 [==============================] - 22s 6ms/step - loss: 0.7130 - dense_2_loss: 0.2297 - dense_3_loss: 0.4832 - dense_2_acc: 0.8577 - dense_3_acc: 0.7666 - val_loss: 5.6834 - val_dense_2_loss: 1.2174 - val_dense_3_loss: 4.4660 - val_dense_2_acc: 0.7897 - val_dense_3_acc: 0.3595
# Epoch 12/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 0.7077 - dense_2_loss: 0.2248 - dense_3_loss: 0.4829 - dense_2_acc: 0.8651 - dense_3_acc: 0.7655 - val_loss: 0.6689 - val_dense_2_loss: 0.2025 - val_dense_3_loss: 0.4665 - val_dense_2_acc: 0.9190 - val_dense_3_acc: 0.8424
# Epoch 13/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 0.6798 - dense_2_loss: 0.2176 - dense_3_loss: 0.4622 - dense_2_acc: 0.8593 - dense_3_acc: 0.7732 - val_loss: 0.6901 - val_dense_2_loss: 0.2078 - val_dense_3_loss: 0.4823 - val_dense_2_acc: 0.9254 - val_dense_3_acc: 0.8199
# Epoch 14/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 0.6961 - dense_2_loss: 0.2196 - dense_3_loss: 0.4766 - dense_2_acc: 0.8646 - dense_3_acc: 0.7688 - val_loss: 1.0604 - val_dense_2_loss: 0.2625 - val_dense_3_loss: 0.7979 - val_dense_2_acc: 0.9068 - val_dense_3_acc: 0.7949
# Epoch 15/20
# 3625/3625 [==============================] - 21s 6ms/step - loss: 0.6615 - dense_2_loss: 0.2065 - dense_3_loss: 0.4550 - dense_2_acc: 0.8687 - dense_3_acc: 0.7821 - val_loss: 0.6593 - val_dense_2_loss: 0.1960 - val_dense_3_loss: 0.4633 - val_dense_2_acc: 0.9273 - val_dense_3_acc: 0.8354
# Epoch 16/20
# 3625/3625 [==============================] - 22s 6ms/step - loss: 0.6626 - dense_2_loss: 0.2127 - dense_3_loss: 0.4499 - dense_2_acc: 0.8673 - dense_3_acc: 0.7752 - val_loss: 3.7370 - val_dense_2_loss: 0.9604 - val_dense_3_loss: 2.7766 - val_dense_2_acc: 0.8064 - val_dense_3_acc: 0.4360
# Epoch 17/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 0.6435 - dense_2_loss: 0.2038 - dense_3_loss: 0.4397 - dense_2_acc: 0.8723 - dense_3_acc: 0.7926 - val_loss: 0.7179 - val_dense_2_loss: 0.1864 - val_dense_3_loss: 0.5315 - val_dense_2_acc: 0.9421 - val_dense_3_acc: 0.8283
# Epoch 18/20
# 3625/3625 [==============================] - 23s 6ms/step - loss: 0.6317 - dense_2_loss: 0.2023 - dense_3_loss: 0.4294 - dense_2_acc: 0.8643 - dense_3_acc: 0.8019 - val_loss: 0.5970 - val_dense_2_loss: 0.1646 - val_dense_3_loss: 0.4324 - val_dense_2_acc: 0.9531 - val_dense_3_acc: 0.8592
# Epoch 19/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 0.6316 - dense_2_loss: 0.2022 - dense_3_loss: 0.4295 - dense_2_acc: 0.8709 - dense_3_acc: 0.7989 - val_loss: 0.6352 - val_dense_2_loss: 0.1760 - val_dense_3_loss: 0.4592 - val_dense_2_acc: 0.9511 - val_dense_3_acc: 0.8630
# Epoch 20/20
# 3625/3625 [==============================] - 24s 7ms/step - loss: 0.6152 - dense_2_loss: 0.2001 - dense_3_loss: 0.4151 - dense_2_acc: 0.8701 - dense_3_acc: 0.8080 - val_loss: 0.7580 - val_dense_2_loss: 0.2290 - val_dense_3_loss: 0.5290 - val_dense_2_acc: 0.8939 - val_dense_3_acc: 0.8206

# %%
#print History graph
historydf = pd.DataFrame(h.history, index=h.epoch)
historydf.plot(ylim=(0,1))

# %%
model.save('model_multi_test.h5')

# %%
#######################  VALIDATION

#dataset = "../../Pics/cleaned1"
#dataset = "../../Pics/mirrored1"
#dataset = "../../Pics/tagged2"
#dataset = "../../Pics/mirrored2"
#dataset = "../../Pics/testTrack"
dataset = "../../Pics/test_noFE_mirrored_3"

#dataset = "../../Pics/Track/OldDataset_balanced"
#dataset = "../../Pics/Track/Datasets_Axionable/ironcar_pics"
#dataset = "../../Pics/Track/Mixed"

#dataset = "../../Pics/BigOne"

# %%
def load_photos_val(directory):
    images = []
    labels_speed = []
    labels_dir = []
    dir_list = listdir(directory)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename, target_size=(96, 160))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # get image id + labels
        value_dir = float(name.split('_')[1])
        value_speed = float(name.split('_')[0])
        labels_dir.append(value_dir)
        labels_speed.append(value_speed)
        images.append(image)
    return images, labels_speed, labels_dir

# %%
# load images from both train and test groups
directory = '../../' + dataset
images_val, labels_speed_val, labels_dir_val = load_photos(directory)
nb_images = len(images_val)
print('Loaded Images and labels: %d' % nb_images)
# Out:
# Loaded Images and labels: 5180

# %%
images_val = np.array(images_val)
images_val /= 255

# %%
# Get predictions
all_preds = model.predict(images_val)

speed_preds = []
for elem in all_preds[0]:
    speed_preds.append(np.argmax(elem))
    
dir_preds = []
for elem in all_preds[1]:
    dir_preds.append(np.argmax(elem))

# %%
res = 0
for i, value in enumerate(speed_preds):
    if value != labels_speed_val[i]:
        res += 1
print("error_rate = " + str(res/i))
# Out:
# error_rate = 0.08148291175902683

# %%
res = 0

i_0 = 1
res_0 = 0
res_0_1 = 0
res_0_2 = 0
res_0_3 = 0
res_0_4 = 0

i_1 = 1
res_1 = 0
res_1_1 = 0
res_1_2 = 0
res_1_3 = 0

i_2 = 1
res_2 = 0
res_2_1 = 0
res_2_2 = 0

i_3 = 1
res_3 = 0
res_3_1 = 0
res_3_2 = 0
res_3_3 = 0

i_4 = 1
res_4 = 0
res_4_1 = 0
res_4_2 = 0
res_4_3 = 0
res_4_4 = 0

for value in labels_dir_val:
    if value == 0:
        i_0 += 1
    elif value == 1:
        i_1 += 1
    elif value == 2:
        i_2 += 1
    elif value == 3:
        i_3 += 1
    elif value == 4:
        i_4 += 1

for i, value in enumerate(dir_preds):
    if value != labels_dir_val[i]:
        res += 1
        if labels_dir_val[i] == 0:    
            res_0 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_0_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_0_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_0_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_0_4 += 1
        elif labels_dir_val[i] == 1:
            res_1 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_1_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_1_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_1_3 += 1
        elif labels_dir_val[i] == 2:
            res_2 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_2_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_2_2 += 1
        elif labels_dir_val[i] == 3:
            res_3 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_3_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_3_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_3_3 += 1
        elif labels_dir_val[i] == 4:
            res_4 += 1
            if abs(labels_dir_val[i] - value) == 1:
                res_4_1 += 1
            elif abs(labels_dir_val[i] - value) == 2:
                res_4_2 += 1
            elif abs(labels_dir_val[i] - value) == 3:
                res_4_3 += 1
            elif abs(labels_dir_val[i] - value) == 4:
                res_4_4 += 1

        
print("total error = " + str(res/i), "0_error = " + str(res_0/i_0), "1_error = " + str(res_1/i_1), "2_error = " + str(res_2/i_2), "3_error = " + str(res_3/i_3), "4_error = " + str(res_4/i_4), )
# Out:
# total error = 0.13361652828731416 0_error = 0.22838499184339314 1_error = 0.01504297994269341 2_error = 0.12885010266940453 3_error = 0.0 4_error = 0.0

# %%
x = ['0','1','2','3','4']
plt.bar(x, height= [res_0/i_0, res_1/i_1, res_2/i_2, res_3/i_3, res_4/i_4])
plt.xticks(x, ['0','1','2','3','4']);
plt.title("Mean Errors by direction")
# Out:
# Text(0.5,1,'Mean Errors by direction')

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_0_1/res_0, res_0_2/res_0, res_0_3/res_0, res_0_4/res_0])
plt.xticks(x, ['1','2','3','4']);
plt.title("0 Errors")
# Out:
# Text(0.5,1,'0 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_1_1/res_1, res_1_2/res_1, res_1_3/res_1])
plt.xticks(x, ['0, 2','3', '4']);
plt.title("1 Errors")
# Out:
# Text(0.5,1,'1 Errors')

# %%
x = ['1','2']
plt.bar(x, height= [res_2_1/res_2, res_2_2/res_2])
plt.xticks(x, ['1, 3','0, 4']);
plt.title("2 Errors")
# Out:
# Text(0.5,1,'2 Errors')

# %%
x = ['1','2','3']
plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
plt.xticks(x, ['2, 4','1', '0']);
plt.title("3 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-43-7793623322ad> in <module>()
#       1 x = ['1','2','3']
# ----> 2 plt.bar(x, height= [res_3_1/res_3, res_3_2/res_3, res_3_3/res_3])
#       3 plt.xticks(x, ['2, 4','1', '0']);
#       4 plt.title("3 Errors")
#
# ZeroDivisionError: division by zero

# %%
x = ['1','2','3','4']
plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
plt.xticks(x, ['3','2','1','0']);
plt.title("4 Errors")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-44-3873ada9ae3b> in <module>()
#       1 x = ['1','2','3','4']
# ----> 2 plt.bar(x, height= [res_4_1/res_4, res_4_2/res_4, res_4_3/res_4, res_4_4/res_4])
#       3 plt.xticks(x, ['3','2','1','0']);
#       4 plt.title("4 Errors")
#
# ZeroDivisionError: division by zero
